# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardo-DRX/PrimeiroProjeto/blob/main/C%C3%B3pia_de_Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# percorrer uma lista
lista_produtos = ["faca", "garfo", "panela", "frigideira", "flarvorstone"]

for produto in lista_produtos:
  print(produto.capitalize())

# percorrendo um dicionario
produtos = {
    "faca": 10,
    "garfo": 10,
    "panela": 200,
    "frigideira": 50,
    "flavorstone": 300,
}

for produto in produtos:
  print(produto)
  print(produtos[produto])
# Out:
# Faca
# Garfo
# Panela
# Frigideira
# Flarvorstone
# faca
# 10
# garfo
# 10
# panela
# 200
# frigideira
# 50
# flavorstone
# 300
